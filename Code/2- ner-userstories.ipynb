# %% [markdown]
# # ******START NEWWWWWWw** ##########################################################

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import spacy
print(spacy.__version__)
import pandas as pd
from spacy import displacy
from spacy.matcher import Matcher
from IPython.display import HTML as html_print



import pandas as pd
import numpy as np
import re


data=pd.read_csv("/kaggle/input/userstoryfinal2/All_user_stories_Final6.csv",encoding="latin1")

data.tail(5)
print("Total Dataset Len:: " , len(data))
TestData = data.sample(frac=0.30)
print("TestData Len:: " , len(TestData))
#print("TestData Index:: " , TestData.index)
TrainData = data.drop(TestData.index)
print("TrainData(without TestData) Len:: " , len(TrainData))
# Out:
# /kaggle/input/OrgAllUserStories/Org_All_user_stories.csv
# /kaggle/input/userstoryfinal2/All_user_stories_Final6.csv
# /kaggle/input/user-stories/user_stories_13.csv
# 2.3.7
# Total Dataset Len::  7118
# TestData Len::  2135
# TrainData(without TestData) Len::  4983

# %%
## Test
doc = data.iloc[1]
doc
UserEnt = doc['user']
startUsr = doc['StoryText'].index( UserEnt )
endUsr = startUsr + (len(UserEnt)-1)
print(doc)
print(UserEnt)
print (startUsr)
print (endUsr)
ff = doc['nonfun']
print(str(ff) == 'nan')
#print("asdfasd "+ str (len(str(ff))) )
# Out:
# id                                                           2
# Story                                                  story 2
# StoryText    As a UI designer, I want to redesign the Resou...
# user                                               UI designer
# fun                                redesign the Resources page
# goal                                       it matches the new
# nonfun                                                     NaN
# Name: 1, dtype: object
# UI designer
# 5
# 15
# True

# %%
def parse_train_data(doc):
    #detections = [(doc[start:end].start_char, doc[start:end].end_char, 'PROGLANG') for idx, start, end in match_User.findall(doc)
    #[doc.index( match_User.findall(doc)[0] , doc.index( match_User.findall(doc)[0][-1]]
    startUsr =-1
    endUsr =-1
    startF =-1 
    endF =-1
    startG =-1 
    endG =-1
    startNonF =-1 
    endNonF =-1
    UserEnt = doc['user']
    FunEnt = doc['fun']
    GoalEnt = doc['goal']
    NonFunEnt = doc['nonfun']#and doc['id'] != 497
    if (str(doc['StoryText']) != 'nan' and len(str(doc['StoryText'])) > 0  ):
        
        if (str(UserEnt) != 'nan' and len(str(UserEnt)) > 0 ):
            #print(str(doc['StoryText']).find(UserEnt) > 0)
            if(str(doc['StoryText']).find(UserEnt) > 0):
                startUsr = str(doc['StoryText']).index( UserEnt )
                endUsr = startUsr + (len(UserEnt))
                #print(doc['StoryText'] + "::" + doc['StoryText'][startUsr:endUsr])

        if (str(FunEnt) != 'nan'):
            if(str(doc['StoryText']).find(FunEnt) > 0):
                startF = str(doc['StoryText']).index( FunEnt ) +1
                endF = startF + (len(FunEnt)-1) -1
                #print(doc['StoryText'] + "::" + doc['StoryText'][startF:endF])

        if (str(GoalEnt) != 'nan'):
            if(str(doc['StoryText']).find(GoalEnt) > 0):
                startG = str(doc['StoryText']).index( GoalEnt ) +1
                endG = startG + (len(GoalEnt)-1) - 1
                #print(doc['StoryText'] + ":::" + doc['StoryText'][startG:endG])

        if (str(NonFunEnt) != 'nan'):
            if(str(doc['StoryText']).find(NonFunEnt) > 0):
                startNonF = str(doc['StoryText']).index( NonFunEnt )
                endNonF = startNonF + (len(NonFunEnt))
                #print(doc['StoryText'] + ":::" + doc['StoryText'][startNonF:endNonF])
        if(startF < endUsr):
            startF = -1
            endF = -1
        if(startG < endF or startG < endUsr ):
            startG = -1
            endG = -1
        if(startNonF < endG or startNonF < endF or startNonF < endUsr):
            startNonF = -1
            endNonF = -1
        #print(doc[startG:endG])
    #match_Func
    #match_Goal
    #return (doc, {'entities': [(startt, endd,'User' ) , (starttF, enddF,'Fun' )  ]}) 
    #return (doc['StoryText'], {'entities': [ (startUsr, endUsr,'User' ) ]}) 
    #return (doc['StoryText'], {'entities': [ (startNonF, endNonF,'Non-Fun' )]}) 
    #return (doc['StoryText'], {'entities': [ (startUsr, endUsr,'User' ) , (startF, endF,'Fun' ) , (startG, endG,'Goal' ), (startNonF, endNonF,'Non-Fun' ) ]}) 
    return (doc['StoryText'], {'entities': [ (startUsr, endUsr,'User' ) , (startF, endF,'Fun' ) , (startG, endG,'Goal' ) ]}) 

#doc3 = "As a moderator, I want to invite estimators by giving them a URL where they can access the game, so that we can start the game."
# {'entities': [(7, 13, 'PROGLANG'),
doc = data.iloc[2]
print(doc)
parse_train_data(doc)
# Out:
# id                                                           3
# Story                                                  story 3
# StoryText    As a UI designer, I want to report to the Agen...
# user                                               UI designer
# fun                                    report to the Agencies
# goal                                        they are aware of
# nonfun                                                  better
# Name: 2, dtype: object
# ('As a UI designer, I want to report to the Agencies about user testing, so that they are aware of their contributions to making Broker a better UX.',
#  {'entities': [(5, 16, 'User'), (28, 50, 'Fun'), (79, 96, 'Goal')]})

# %%
nlp = spacy.load("en_core_web_sm")

# %%
#TRAIN_DATA = [parse_train_data(d) for d in data ]
#TRAIN_DATA[5:8]
#len(df)
#for index, row in data.tail(2).iterrows():
#    print(row["user"], row["fun"])

#TRAIN_DATA = [parse_train_data(dd) for index, dd in data[1:1000].iterrows() ]
TRAIN_DATA = [parse_train_data(dd) for index, dd in TrainData.iterrows() ] 
TRAIN_DATA
#TRAIN_DATA[2000:2010]

def create_blank_nlp(train_data):
    nlp = spacy.blank("en")
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
    ner = nlp.get_pipe("ner")
    for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
    return nlp

#type(TRAIN_DATA)
#len(TRAIN_DATA)
#151


#for index, dd in data.iterrows():
#    print(dd)
#    parse_train_data(dd)

#for i in range(5):
#    print(data.loc[i])

# %%
from spacy.util import minibatch, compounding

import random 
import datetime as dt

# %%
def trim_entity_spans(data: list) -> list:
    """Removes leading and trailing white spaces from entity spans.

    Args:
        data (list): The data to be cleaned in spaCy JSON format.

    Returns:
        list: The cleaned data.
    """
    invalid_span_tokens = re.compile(r'\s')

    cleaned_data = []
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        for start, end, label in entities:
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])

    return cleaned_data

# %%
dddd = trim_entity_spans(TRAIN_DATA)

# %%
#len(TRAIN_DATA)   #2193
nlp = create_blank_nlp(dddd)
optimizer = nlp.begin_training()
for i in range(10):
    losses = {}
    batches = minibatch(dddd, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
            texts,  # batch of texts
            annotations,  # batch of annotations
            drop=0.1,  # dropout - make it harder to memorise data
            losses=losses,
        )
    print(f"Losses at iteration {i} - {dt.datetime.now()} {losses}")
# Out:
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:639: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   **kwargs
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:639: UserWarning: [W034] Please install the package spacy-lookups-data in order to include the default lexeme normalization table for the language 'en'.
#   **kwargs
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Broker user, I want  to help create content m..." with entities "[[5, 16, 'User'], [29, 55, 'Fun'], [72, 98, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a UI designer, I want to schedule user testing,..." with entities "[[5, 16, 'User'], [28, 48, 'Fun'], [65, 90, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want the publish button in FABS to de..." with entities "[[5, 9, 'User'], [48, 72, 'Fun'], [127, 153, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer , I want my domain models to be ind..." with entities "[[5, 14, 'User'], [44, 62, 'Fun'], [79, 106, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want the data loaded from histor..." with entities "[[5, 14, 'User'], [63, 90, 'Fun'], [107, 132, 'Goa...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a FABS user, I want the language on FABS pages ..." with entities "[[5, 14, 'User'], [53, 73, 'Fun'], [84, 101, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Applicant, I want to Submit Supporting Docum..." with entities "[[6, 15, 'User'], [27, 57, 'Fun'], [74, 112, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Applicant, I want to Modify my Application, ..." with entities "[[6, 15, 'User'], [27, 47, 'Fun'], [64, 98, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Record an Internal No..." with entities "[[5, 17, 'User'], [29, 51, 'Fun'], [68, 96, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Apply a Hold, so that..." with entities "[[5, 17, 'User'], [29, 40, 'Fun'], [57, 88, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Remove a Hold, so tha..." with entities "[[5, 17, 'User'], [29, 41, 'Fun'], [58, 87, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Manage Approved Proff..." with entities "[[5, 17, 'User'], [29, 52, 'Fun'], [69, 95, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Schedule a Meeting, s..." with entities "[[5, 17, 'User'], [29, 46, 'Fun'], [63, 89, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Zoning Staff member, I want to Issue the Zoni..." with entities "[[5, 24, 'User'], [36, 67, 'Fun'], [84, 114, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Develop a Staff Repor..." with entities "[[5, 17, 'User'], [29, 50, 'Fun'], [67, 93, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want toAssign a Hearing Date,..." with entities "[[5, 17, 'User'], [26, 48, 'Fun'], [65, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Applicant, I want to Satisfy Hearing Require..." with entities "[[6, 15, 'User'], [27, 54, 'Fun'], [71, 106, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Capture a Hearing Dec..." with entities "[[5, 17, 'User'], [29, 54, 'Fun'], [71, 89, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Staff member, I want to Process the Appeals, ..." with entities "[[5, 17, 'User'], [29, 47, 'Fun'], [64, 85, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Plan Review Staff member, I want toAssign Pla..." with entities "[[5, 29, 'User'], [38, 62, 'Fun'], [79, 109, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Plan Review Staff Supervisor, I want to Manag..." with entities "[[5, 33, 'User'], [45, 73, 'Fun'], [90, 120, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Development Staff member, I want to Issue a D..." with entities "[[5, 29, 'User'], [41, 74, 'Fun'], [91, 111, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Applicant, I want to Complete Building Devel..." with entities "[[6, 15, 'User'], [27, 63, 'Fun'], [80, 103, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Inspection Staff member, I want to Create an..." with entities "[[6, 29, 'User'], [41, 60, 'Fun'], [77, 110, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a l Staff member, I want to search for Property..." with entities "[[5, 19, 'User'], [31, 61, 'Fun'], [78, 110, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to click on the address, so that..." with entities "[[5, 9, 'User'], [21, 40, 'Fun'], [51, 65, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a developer, I want to attend some UI/UX lesson..." with entities "[[5, 14, 'User'], [26, 50, 'Fun'], [67, 89, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to upload my week's schedule, so..." with entities "[[5, 9, 'User'], [21, 45, 'Fun'], [62, 95, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to contact the administrators, s..." with entities "[[5, 9, 'User'], [21, 46, 'Fun'], [63, 86, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an admin, I want to add recycling center inform..." with entities "[[6, 11, 'User'], [23, 54, 'Fun'], [71, 99, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a superuser, I want to reply to user questions,..." with entities "[[5, 14, 'User'], [26, 48, 'Fun'], [65, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want an Elasticsearch integratio..." with entities "[[5, 14, 'User'], [23, 50, 'Fun'], [67, 100, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want an SPSS integration, so tha..." with entities "[[5, 14, 'User'], [23, 41, 'Fun'], [58, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want an EPrints integration, so ..." with entities "[[5, 14, 'User'], [23, 44, 'Fun'], [61, 94, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want a Mongo integration, so tha..." with entities "[[5, 14, 'User'], [23, 41, 'Fun'], [58, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Developer, I want a DAT integration, so that ..." with entities "[[5, 14, 'User'], [23, 39, 'Fun'], [56, 89, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a developer, I want an DSpace integration, so t..." with entities "[[5, 14, 'User'], [23, 43, 'Fun'], [60, 93, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a ResearcherPublisher, I want an integration wi..." with entities "[[5, 24, 'User'], [33, 58, 'Fun'], [69, 84, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Researcher, I want an integration with https:..." with entities "[[5, 15, 'User'], [24, 69, 'Fun'], [86, 107, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a site editor, I want to maintain a FAQ section..." with entities "[[5, 16, 'User'], [28, 49, 'Fun'], [60, 85, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user researcher, I want to have the WIG proto..." with entities "[[5, 20, 'User'], [32, 53, 'Fun'], [70, 94, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a CMS administrator, I want to have roles, so t..." with entities "[[5, 22, 'User'], [34, 38, 'Fun'], [60, 82, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a team member, I want to have a prototype strat..." with entities "[[5, 16, 'User'], [28, 52, 'Fun'], [63, 82, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an NSF employee, I want to schedule regular in-..." with entities "[[6, 18, 'User'], [30, 65, 'Fun'], [76, 94, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user researcher, I want to begin identifying ..." with entities "[[5, 20, 'User'], [32, 71, 'Fun'], [88, 117, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a team member, I want to know when meetings are..." with entities "[[5, 16, 'User'], [28, 49, 'Fun'], [66, 70, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a moderator, I want to browse through previous ..." with entities "[[5, 14, 'User'], [26, 54, 'Fun'], [71, 93, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a moderator, I want to delete a game, so that s..." with entities "[[5, 14, 'User'], [26, 38, 'Fun'], [49, 74, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a moderator, I want to delete my account, so th..." with entities "[[5, 14, 'User'], [26, 42, 'Fun'], [53, 82, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a developer, I want to have the application fun..." with entities "[[5, 14, 'User'], [26, 55, 'Fun'], [137, 165, 'Goa...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Publisher, I want to publish a dataset, so th..." with entities "[[5, 14, 'User'], [26, 42, 'Fun'], [59, 80, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Publisher, I want to publish a dataset, so th..." with entities "[[5, 14, 'User'], [26, 42, 'Fun'], [59, 85, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Publisher, I want to configure my client, so ..." with entities "[[5, 14, 'User'], [26, 44, 'Fun'], [61, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Publisher, I want to unpublish a data package..." with entities "[[5, 14, 'User'], [26, 49, 'Fun'], [60, 75, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a consumer, I want to view the data package, so..." with entities "[[5, 13, 'User'], [25, 45, 'Fun'], [56, 70, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Consumer, I want to browse and find publisher..." with entities "[[5, 13, 'User'], [25, 50, 'Fun'], [61, 76, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Consumer, I want to view a publisher's profil..." with entities "[[5, 13, 'User'], [25, 50, 'Fun'], [61, 75, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a developer, I want to take a dataset offline, ..." with entities "[[5, 14, 'User'], [26, 47, 'Fun'], [64, 98, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an OlderPerson, I want to have everything prein..." with entities "[[6, 17, 'User'], [29, 56, 'Fun'], [67, 80, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a trainee, I want to must accept the cancellati..." with entities "[[5, 12, 'User'], [24, 52, 'Fun'], [84, 108, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a anonymoususer, I want to view venue details, ..." with entities "[[5, 18, 'User'], [30, 47, 'Fun'], [64, 78, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a attendee, I want to register for a summit, so..." with entities "[[5, 13, 'User'], [25, 45, 'Fun'], [62, 80, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a anonymoususer, I want to learn about sponsors..." with entities "[[5, 18, 'User'], [30, 59, 'Fun'], [76, 101, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a sponsor, I want to post a job, so that I can ..." with entities "[[5, 12, 'User'], [24, 33, 'Fun'], [50, 77, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a authenticateduser, I want to view the job boa..." with entities "[[5, 22, 'User'], [34, 51, 'Fun'], [68, 91, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a anonymoususer, I want to see the schedule, so..." with entities "[[5, 18, 'User'], [30, 45, 'Fun'], [62, 77, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a administrator, I want to bulk approve session..." with entities "[[5, 18, 'User'], [30, 61, 'Fun'], [78, 82, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a authenticateduser, I want to edit my session,..." with entities "[[5, 22, 'User'], [34, 48, 'Fun'], [59, 70, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a sponsor, I want to personalize my sponsorship..." with entities "[[5, 12, 'User'], [24, 54, 'Fun'], [71, 87, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a anonymoususer, I want to find session informa..." with entities "[[5, 18, 'User'], [30, 53, 'Fun'], [70, 85, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a PI, I want to properly record all metadata, s..." with entities "[[5, 7, 'User'], [19, 46, 'Fun'], [63, 87, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a legalofficer, I want to know about data sensi..." with entities "[[5, 17, 'User'], [29, 55, 'Fun'], [72, 97, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a stakeholder, I want to know who is responsibl..." with entities "[[5, 16, 'User'], [28, 51, 'Fun'], [79, 108, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to know about costs, so th..." with entities "[[5, 15, 'User'], [27, 42, 'Fun'], [59, 75, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a depositor, I want to deposit arbitrarily larg..." with entities "[[5, 14, 'User'], [26, 56, 'Fun'], [67, 83, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an archivist, I want to mark individual filesAs..." with entities "[[6, 15, 'User'], [27, 60, 'Fun'], [71, 92, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an archivist, I want to automatically generate ..." with entities "[[6, 15, 'User'], [27, 67, 'Fun'], [78, 93, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to generate structured cit..." with entities "[[5, 15, 'User'], [27, 59, 'Fun'], [70, 83, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to share reports I've writ..." with entities "[[5, 15, 'User'], [27, 52, 'Fun'], [63, 81, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to download a file, so tha..." with entities "[[5, 15, 'User'], [27, 41, 'Fun'], [58, 77, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to search by keyword, so t..." with entities "[[5, 15, 'User'], [27, 43, 'Fun'], [60, 85, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an archivist, I want to search by tag, so that ..." with entities "[[6, 15, 'User'], [27, 39, 'Fun'], [50, 77, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAssistant archivist, I want to easily access ..." with entities "[[5, 24, 'User'], [33, 67, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to search using structured..." with entities "[[5, 15, 'User'], [27, 54, 'Fun'], [71, 98, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to access tagged working p..." with entities "[[5, 15, 'User'], [27, 54, 'Fun'], [65, 87, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a researcher, I want to view thumbnails of phot..." with entities "[[5, 15, 'User'], [27, 51, 'Fun'], [68, 87, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an researcher, I want to view film clips, so th..." with entities "[[6, 16, 'User'], [28, 42, 'Fun'], [59, 80, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an archivist, I want to view collection files, ..." with entities "[[6, 15, 'User'], [27, 47, 'Fun'], [64, 95, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an administrator, I want to create user roles, ..." with entities "[[6, 19, 'User'], [31, 47, 'Fun'], [64, 83, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an administrator, I want toAssign RAC staff to ..." with entities "[[6, 19, 'User'], [50, 70, 'Fun'], [87, 112, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a library staff member, I want to access useful..." with entities "[[5, 25, 'User'], [37, 68, 'Fun'], [192, 217, 'Goa...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to beAssured that the d..." with entities "[[5, 18, 'User'], [30, 56, 'Fun'], [103, 124, 'Goa...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to beAssured that threa..." with entities "[[5, 18, 'User'], [27, 52, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to beAssured that the r..." with entities "[[5, 18, 'User'], [27, 48, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to beAssured that theAs..." with entities "[[5, 18, 'User'], [27, 54, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to know what the intell..." with entities "[[5, 18, 'User'], [30, 56, 'Fun'], [129, 149, 'Goa...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to have a mechanism to ..." with entities "[[5, 18, 'User'], [27, 46, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As anAsset manager, I want to beAssured that fundi..." with entities "[[5, 18, 'User'], [27, 52, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a stakeholder, I want to have files adequately ..." with entities "[[5, 16, 'User'], [28, 58, 'Fun'], [75, 102, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a site admin, I need to approve each help wante..." with entities "[[5, 15, 'User'], [50, 69, 'Fun'], [90, 107, 'Goal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a site admin, I can edit and delete help wanted..." with entities "[[5, 15, 'User'], [49, 63, 'Fun'], [-1, -1, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a Certified Scrum Trainer, I can pay an annual ..." with entities "[[5, 28, 'User'], [36, 51, 'Fun'], [62, 78, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a site visitor, I can create an account so that..." with entities "[[5, 17, 'User'], [25, 40, 'Fun'], [57, 74, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# ...
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an individual client, I want to continuAs a gue..." with entities "[[6, 23, 'User'], [35, 51, 'Fun'], [68, 87, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to update my user profile, s..." with entities "[[5, 13, 'User'], [25, 46, 'Fun'], [57, 76, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to update my user profile, so ..." with entities "[[5, 11, 'User'], [23, 44, 'Fun'], [55, 74, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to update my user profile, s..." with entities "[[5, 13, 'User'], [25, 46, 'Fun'], [57, 76, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to modify my user profile, so th..." with entities "[[5, 9, 'User'], [21, 42, 'Fun'], [53, 72, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to update my customer profile, s..." with entities "[[5, 9, 'User'], [21, 46, 'Fun'], [57, 76, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to update my client profile, so ..." with entities "[[5, 9, 'User'], [21, 44, 'Fun'], [55, 74, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to update food item, so that..." with entities "[[5, 13, 'User'], [25, 40, 'Fun'], [51, 73, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to update food item, so that i..." with entities "[[5, 11, 'User'], [23, 38, 'Fun'], [49, 71, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to update food item, so that..." with entities "[[5, 13, 'User'], [25, 40, 'Fun'], [51, 73, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to edit food item, so that it re..." with entities "[[5, 9, 'User'], [21, 34, 'Fun'], [45, 67, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to modify food item, so that it ..." with entities "[[5, 9, 'User'], [21, 36, 'Fun'], [47, 69, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to update food object, so that i..." with entities "[[5, 9, 'User'], [21, 38, 'Fun'], [49, 71, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a user, I want to update food item, so that it ..." with entities "[[5, 9, 'User'], [21, 36, 'Fun'], [47, 69, 'Goal']...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to create meal automatically..." with entities "[[5, 13, 'User'], [25, 49, 'Fun'], [60, 73, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to see meal details, so that..." with entities "[[5, 13, 'User'], [25, 40, 'Fun'], [57, 78, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to see meal details, so that I..." with entities "[[5, 11, 'User'], [23, 38, 'Fun'], [55, 76, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to see my meal calendar, so ..." with entities "[[5, 13, 'User'], [25, 44, 'Fun'], [61, 78, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to see my meal calendar, so th..." with entities "[[5, 11, 'User'], [23, 42, 'Fun'], [59, 76, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to view my account's profile..." with entities "[[5, 13, 'User'], [25, 49, 'Fun'], [66, 95, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to view my account's profile, ..." with entities "[[5, 11, 'User'], [23, 47, 'Fun'], [64, 93, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to view my account's profile..." with entities "[[5, 13, 'User'], [25, 49, 'Fun'], [66, 95, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to view my meal book, so I c..." with entities "[[5, 13, 'User'], [25, 41, 'Fun'], [47, 63, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to view my grocery list, so ..." with entities "[[5, 13, 'User'], [25, 44, 'Fun'], [50, 66, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to view my grocery list, so I ..." with entities "[[5, 11, 'User'], [23, 42, 'Fun'], [48, 64, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to view my grocery list, so ..." with entities "[[5, 13, 'User'], [25, 44, 'Fun'], [50, 66, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to have facebook like button..." with entities "[[5, 13, 'User'], [25, 49, 'Fun'], [55, 72, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a customer, I want to have a twitter button, so..." with entities "[[5, 13, 'User'], [25, 45, 'Fun'], [51, 67, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a client, I want to have a twitter button, so I..." with entities "[[5, 11, 'User'], [23, 43, 'Fun'], [49, 65, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As a end user, I want to have a twitter button, so..." with entities "[[5, 13, 'User'], [25, 45, 'Fun'], [51, 67, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Editor, I want to immediately start the tool..." with entities "[[6, 12, 'User'], [24, 49, 'Fun'], [60, 73, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Editor, I want to rapidly start the tool, so..." with entities "[[6, 12, 'User'], [24, 45, 'Fun'], [56, 69, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /opt/conda/lib/python3.7/site-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "As an Editor, I want to instantly start the tool, ..." with entities "[[6, 12, 'User'], [24, 47, 'Fun'], [58, 71, 'Goal'...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# Losses at iteration 0 - 2022-11-29 10:51:27.848994 {'ner': 20432.818416058064}
# Losses at iteration 1 - 2022-11-29 10:52:09.630832 {'ner': 7852.549156186068}
# Losses at iteration 2 - 2022-11-29 10:52:51.813039 {'ner': 5898.792710987397}
# Losses at iteration 3 - 2022-11-29 10:53:41.037596 {'ner': 5022.840708941802}
# Losses at iteration 4 - 2022-11-29 10:54:30.430904 {'ner': 4167.891463072393}
# Losses at iteration 5 - 2022-11-29 10:55:19.221830 {'ner': 3533.0406039811214}
# Losses at iteration 6 - 2022-11-29 10:56:08.369696 {'ner': 2911.424782074173}
# Losses at iteration 7 - 2022-11-29 10:56:57.253305 {'ner': 2620.3245790739675}
# Losses at iteration 8 - 2022-11-29 10:57:46.602717 {'ner': 2275.1868632412143}
# Losses at iteration 9 - 2022-11-29 10:58:35.393219 {'ner': 2490.0870022306985}

# %%
nlp.pipeline
print(nlp.pipe_names)
# Out:
# ['ner']

# %%
    
#TRAIN_DATA[5:8]
doc = nlp("As a Plan Review Staff Supervisor, I want to Manage Plan Reviewer Workload, so that I can monitor and effectively adjust workloadAs necessary and ensure service levels are met")
doc2 = nlp("As a UI designer, I want to report to the Agencies about user testing, so that they are aware of their contributions to making Broker a better UX.")
doc3 = nlp("As a tester, I want to ensure that FABS is deriving fields properly through a robust test file plus a follow up check." )
#nlp(dd) for index, dd in data.iterrows()
#nlp(dd) for index, dd in data.iterrows()
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)
print(doc.ents)
displacy.render(doc, style="ent")
displacy.render(doc2, style="ent")
displacy.render(doc3, style="ent")
# Out:
# [('Plan Review Staff Supervisor', 5, 33, 'User'), ('Manage Plan Reviewer Workload', 45, 74, 'Fun'), ('monitor and effectively adjust', 90, 120, 'Goal')]
# (Plan Review Staff Supervisor, Manage Plan Reviewer Workload, monitor and effectively adjust)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plan Review Staff Supervisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">User</span>
# </mark>
# , I want to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Manage Plan Reviewer Workload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Fun</span>
# </mark>
# , so that I can
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monitor and effectively adjust
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Goal</span>
# </mark>
#  workloadAs necessary and ensure service levels are met</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UI designer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">User</span>
# </mark>
# , I want to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     report to the Agencies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Fun</span>
# </mark>
#  about user testing, so that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     they are aware of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Goal</span>
# </mark>
#  their contributions to making Broker a better UX.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">As a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tester
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">User</span>
# </mark>
# , I want
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     to ensure that FABS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Fun</span>
# </mark>
#  is deriving fields properly through a robust test file plus a follow up check.</div></span>

# %% [markdown]
# # **NEW Evaluation##############################**

# %%
#data=pd.read_csv("/kaggle/input/userstoryfinal2/All_user_stories_Final5.csv",encoding="latin1") 
#print("Data Len:: " , len(data))
#data.tail(5)
#type(data)
TestData_22 = data.sample(frac=0.30)
print("TestData_22 Len:: " , len(TestData_22))
#print("TestData_22 Index:: " , TestData_22.index)
TrainData_22 = data.drop(TestData_22.index)
print("TrainData_22(without TestData_22) Len:: " , len(TrainData_22))

#sample

# Just to check there is no overlap between Train and Test Dataset
i = 2035
print('#####################')
rslt_test = TestData_22[TestData_22['id'] == i] 
print('\nResult TestData_22 :\n', rslt_test)
print('#####################')

rslt_train = TrainData_22[TrainData_22['id'] == i] 
print('\nResult TrainData_22 :\n', rslt_train)
# Out:
# TestData_22 Len::  2135
# TrainData_22(without TestData_22) Len::  4983
# #####################
#
# Result TestData_22 :
#  Empty DataFrame
# Columns: [id, Story, StoryText, user, fun, goal, nonfun]
# Index: []
# #####################
#
# Result TrainData_22 :
#          id       Story                                          StoryText  \
# 2057  2035  story 2035  As a user, I want to view my session history, ...
#
#       user                       fun             goal nonfun
# 2057  user   view my session history   I can see how     NaN

# %%
def parse_test_data_ForEval(doc):
    #detections = [(doc[start:end].start_char, doc[start:end].end_char, 'PROGLANG') for idx, start, end in match_User.findall(doc)
    #[doc.index( match_User.findall(doc)[0] , doc.index( match_User.findall(doc)[0][-1]]
    startUsr =-1
    endUsr =-1
    startF =-1 
    endF =-1
    startG =-1 
    endG =-1
    startNonF =-1 
    endNonF =-1
    UserEnt = doc['user']
    FunEnt = doc['fun']
    GoalEnt = doc['goal']
    NonFunEnt = doc['nonfun']#and doc['id'] != 497
    if (str(doc['StoryText']) != 'nan' and len(str(doc['StoryText'])) > 0  ):
        
        if (str(UserEnt) != 'nan' and len(str(UserEnt)) > 0 ):
            #print(str(doc['StoryText']).find(UserEnt) > 0)
            if(str(doc['StoryText']).find(UserEnt) > 0):
                startUsr = str(doc['StoryText']).index( UserEnt )
                endUsr = startUsr + (len(UserEnt))
                #print(doc['StoryText'] + "::" + doc['StoryText'][startUsr:endUsr])

        if (str(FunEnt) != 'nan'):
            if(str(doc['StoryText']).find(FunEnt) > 0):
                startF = str(doc['StoryText']).index( FunEnt ) +1
                endF = startF + (len(FunEnt)-1) -1
                #print(doc['StoryText'] + "::" + doc['StoryText'][startF:endF])

        if (str(GoalEnt) != 'nan'):
            if(str(doc['StoryText']).find(GoalEnt) > 0):
                startG = str(doc['StoryText']).index( GoalEnt ) +1
                endG = startG + (len(GoalEnt)-1) - 1
                #print(doc['StoryText'] + ":::" + doc['StoryText'][startG:endG])

        if (str(NonFunEnt) != 'nan'):
            if(str(doc['StoryText']).find(NonFunEnt) > 0):
                startNonF = str(doc['StoryText']).index( NonFunEnt )
                endNonF = startNonF + (len(NonFunEnt))
                #print(doc['StoryText'] + ":::" + doc['StoryText'][startNonF:endNonF])
        if(startF < endUsr):
            startF = -1
            endF = -1
        if(startG < endF or startG < endUsr ):
            startG = -1
            endG = -1
        if(startNonF < endG or startNonF < endF or startNonF < endUsr):
            startNonF = -1
            endNonF = -1
        #print(doc[startG:endG])
    #match_Func
    #match_Goal
    #return (doc, {'entities': [(startt, endd,'User' ) , (starttF, enddF,'Fun' )  ]}) 
    #return (doc['StoryText'], {'entities': [ (startUsr, endUsr,'User' ) ]}) 
    #return (doc['StoryText'], {'entities': [ (startNonF, endNonF,'Non-Fun' )]}) 
    pred = nlp(str(doc['StoryText']))
    return ([{'label': 'User' , "start":startUsr , "end": endUsr } , 
                            {'label': 'Fun' , "start": startF , "end": endF },
                            {'label': 'Goal' , "start": startG , "end": endG }] ,
            [{'label':  e.label_ , "start":e.start_char , "end": e.end_char }  for e in pred.ents])
    #[ {startUsr, endUsr,'User' } , (startF, endF,'Fun' ) , (startG, endG,'Goal' ), (startNonF, endNonF,'Non-Fun' ) ]}) 

#doc3 = "As a moderator, I want to invite estimators by giving them a URL where they can access the game, so that we can start the game."
# {'entities': [(7, 13, 'PROGLANG'),
doc2 = data.iloc[2]
print(doc2)
print (parse_test_data_ForEval(doc2)[0])
print(parse_test_data_ForEval(doc2)[1])
# Out:
# id                                                           3
# Story                                                  story 3
# StoryText    As a UI designer, I want to report to the Agen...
# user                                               UI designer
# fun                                    report to the Agencies
# goal                                        they are aware of
# nonfun                                                  better
# Name: 2, dtype: object
# [{'label': 'User', 'start': 5, 'end': 16}, {'label': 'Fun', 'start': 28, 'end': 50}, {'label': 'Goal', 'start': 79, 'end': 96}]
# [{'label': 'User', 'start': 5, 'end': 16}, {'label': 'Fun', 'start': 28, 'end': 50}, {'label': 'Goal', 'start': 79, 'end': 96}]

# %%
#TestData.head(5)

#for index, row in TestData.head(5).iterrows():
#    print(index, row)

tttt = [parse_test_data_ForEval(dd) for index, dd in TestData.iterrows() ] 
#print(tttt)
#type(tttt)
print("##################")
#[print(x[0]) for x in tttt]
true = [x[0] for x in tttt]
#print(true)
print("##################")
#[print([x[1]]) for x in tttt]
predd = [x[1] for x in tttt]
#print(predd)
# Out:
# ##################
# ##################

# %%
pip install nervaluate
# Out:
# Collecting nervaluate
#   Downloading nervaluate-0.1.8-py3-none-any.whl (24 kB)
# Installing collected packages: nervaluate
# Successfully installed nervaluate-0.1.8
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Note: you may need to restart the kernel to use updated packages.

# %%
from nervaluate import Evaluator
evaluator = Evaluator(true, predd, tags=['User', 'Fun', 'Goal'])

# Returns overall metrics and metrics for each tag

results, results_per_tag = evaluator.evaluate()

print(results)
# Out:
# {'ent_type': {'correct': 5319, 'incorrect': 2, 'partial': 0, 'missed': 1084, 'spurious': 27, 'possible': 6405, 'actual': 5348, 'precision': 0.9945774121166792, 'recall': 0.8304449648711943, 'f1': 0.9051306049519271}, 'partial': {'correct': 4956, 'incorrect': 0, 'partial': 365, 'missed': 1084, 'spurious': 27, 'possible': 6405, 'actual': 5348, 'precision': 0.9608264771877337, 'recall': 0.802263856362217, 'f1': 0.8744150429677529}, 'strict': {'correct': 4956, 'incorrect': 365, 'partial': 0, 'missed': 1084, 'spurious': 27, 'possible': 6405, 'actual': 5348, 'precision': 0.9267015706806283, 'recall': 0.7737704918032787, 'f1': 0.843359142346635}, 'exact': {'correct': 4956, 'incorrect': 365, 'partial': 0, 'missed': 1084, 'spurious': 27, 'possible': 6405, 'actual': 5348, 'precision': 0.9267015706806283, 'recall': 0.7737704918032787, 'f1': 0.843359142346635}}

# %%
doc = nlp("As a Plan Review Staff Supervisor, I want to Manage Plan Reviewer Workload, so that I can monitor and effectively adjust workloadAs necessary and ensure service levels are met")
doc2 = nlp("As a UI designer, I want to report to the Agencies about user testing, so that they are aware of their contributions to making Broker a better UX.")
doc3 = nlp("As a tester, I want to ensure that FABS is deriving fields properly through a robust test file plus a follow up check." )
#nlp(dd) for index, dd in data.iterrows()
#nlp(dd) for index, dd in data.iterrows()
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)
ents2 = [{'label':  e.label_ , "start":e.start_char , "end": e.end_char }  for e in doc.ents]
print(ents2)
# Out:
# [('Plan Review Staff Supervisor', 5, 33, 'User'), ('monitor and effectively adjust', 90, 120, 'Goal')]
# [{'label': 'User', 'start': 5, 'end': 33}, {'label': 'Goal', 'start': 90, 'end': 120}]
